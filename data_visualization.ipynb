# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])
plt.ylabel('Hmm numbers')
plt.show()

# %%
plt.plot([ x for x in range(1,10)] , [y**2 for y in range(1,10)] , 'ro' , [ x for x in range(1,10)] , [ x**3 for x in range(1,10)] , 'g*')
